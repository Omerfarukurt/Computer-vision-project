# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model=YOLO("yolov8n.pt")

# %%
video_path=r"C:\dl_proje\image_process\YOLO_arac_takibi\IMG_5268.MOV"

# %%
cap=cv2.VideoCapture(video_path) #video giris kaynagı

# %%
#cıkıs kaynagı için ayar
width=int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) #video genisligi
height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) #video yüksekligi
fps=cap.get(cv2.CAP_PROP_FPS) #bir saniyed ki kare sayısı

# %%
out=cv2.VideoWriter("output.avi",cv2.VideoWriter_fourcc(*"XVID"),fps,(width,height))

# %%
from ultralytics import YOLO
import cv2
import torch

model = YOLO("yolov8n.pt")

cap = cv2.VideoCapture(video_path)

frame_count = 0

while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    frame_count += 1

    # 540p'ye düşür
    frame_small = cv2.resize(frame, (960, 540))

    results = model.track(
        frame_small,
        persist=False,
        conf=0.3
    )

    annotated_frame = results[0].plot()

    cv2.imshow("tracking", annotated_frame)

    if frame_count % 30 == 0:
        torch.cuda.empty_cache()

    if cv2.waitKey(30) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 cars, 58.2ms
# Speed: 18.9ms preprocess, 58.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 11.8ms
# Speed: 2.5ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 8.3ms
# Speed: 2.2ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 7.7ms
# Speed: 2.7ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 10.0ms
# ...

# %%
print("Width:", cap.get(cv2.CAP_PROP_FRAME_WIDTH))
print("Height:", cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print("FPS:", cap.get(cv2.CAP_PROP_FPS))
# Out:
# Width: 1920.0
# Height: 1080.0
# FPS: 29.977957384276266
